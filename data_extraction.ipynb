# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install patool
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import os
import patoolib

# %%
rar_path = '/content/drive/MyDrive/ColabProjects/retinal-disease-detection-oct-cnn/data/downsampled_datasets.rar'
target_directory = '/content/drive/MyDrive/ColabProjects/retinal-disease-detection-oct-cnn/data'

# %%
patoolib.extract_archive(rar_path, outdir=target_directory)
